# %% [markdown]
# $$f=x^2-2x-2 \cos(x) \to min$$
# $$x \in [-0.5; 1]$$
# $$|f(x')-f(x'')| \leq L |x'-x''|$$
# $$f'(x) = 2x - 2 + 2 \sin(x)$$
# $$f''(x) = 2+2\cos(x)$$
# $$L = max |2x - 2 + 2 \sin(x)|_{[-0.5,1]}\leq|2x|_{[-0.5,1]} + |2| + |2 \sin(x)|_{[-0.5,1]}\leq|2x|_{1} + 2 + 2 = 6$$

# %%
from optimization import *
import collections

# %%
a = -0.5
b = 1
N = 100
x_space = np.linspace(a,b,100)
plt.plot(x_space,der_function(x_space), label = "derivative")
plt.plot(x_space,function(x_space), label = "function")
plt.grid(True)
plt.legend()
plt.show()

# %%
# %matplotlib inline

f_brute, x_brute, n_steps = brute_force(-0.5, 1, size=150, live=False)
print(function(x_brute), x_brute, n_steps)
# Out:
# -2.5053890152915024 0.51 150

# %% [markdown]
# $$\varepsilon\sim\dfrac{b-a}{N}\implies N\sim\dfrac{b-a}{\varepsilon}$$
# Заданная точность: $\varepsilon = 0.001$
# $$\implies N = \[\dfrac{b-a}{0.001}\] = 1500$$

# %%
bitwise(-0.5,1,epsilon=0.001,live=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 bitwise(-0.5,1,epsilon=0.001,live=True)
#
# File ~\optimization\1d_optimize\optimization.py:86, in bitwise(a, b, epsilon, live)
#      84     list_f.append(f_0)
#      85     if live:
# ---> 86         live_plot(list_x, list_f, a, b, title='Bitwise')
#      87     size += 1
#      88 return f_0, x_0, size
#
# File ~\optimization\1d_optimize\optimization.py:28, in live_plot(data_x, data_f, a, b, title)
#      26 x_space = np.linspace(a, b, 100)
#      27 for i in range(len(data_f)):
# ---> 28     plt.scatter(data_x, data_f, color='red', s=6)
#      29 plt.plot(x_space, function(x_space), label="function")
#      30 plt.title(title)
#
# ...

# %% [markdown]
# Let $x_1<x_2$, then:
# If $f(x_1)\leq f(x_2)\implies x\in [a,x_2]$
# Or $f(x_1)> f(x_2)\implies x\in [x_1,b]$
# Assuming $\delta \in [0,2\varepsilon]$
# $\varepsilon = 0.001 \implies \delta = 0.001$

# %%
dichotomy(-0.5,1,epsilon=0.001,live=True)
# Out:
# (-2.505390786675017, 0.5109343261718748, 11)

# %%
gold_section(-0.5,1,epsilon=0.001,live=True)
# Out:
# (-2.5053907624481857, 0.5108531433126586, 14)

# %%
parabolic(-0.5,1,live=True)
# Out:
# (-2.505390740498634, 0.5111352711775969, 3)

# %%
newton(-0.5,1,live=True)
# Out:
# (-2.505390789504511, 0.5109692101107746, 2)

# %%
markward(-0.5, 1, live=True)
# Out:
# (-2.505389277979889, 0.5100749433940998, 5)

# %%
polylines(-0.5, 1, 200, epsilon=0.001)
# Out:
# (-2.5053907841169196, 0.5110272382094891, 14)
